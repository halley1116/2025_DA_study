# %% [markdown]
# # 1주차
# - Predicting Insurance Premium
# - 의료보험 데이터를 활용해서 보험료를 예측하는 회귀문제

# %% [markdown]
# ## 데이터 이해
# - charges: 보험료, 종속변수
# - age: 나이
# - gender: 성별
# - bmi: body mass index, 체질량 지수
# - children: 자녀 수
# - smoker: 흡연 여부
# - region: 거주 지역
# - medical_history: 질병 이력
# - family_medical_history: 가족 질병 이력
# - exercise_frequency: 운동 빈도
# - occupation: 직업 종류
# - coverage_level: 보험 종류

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
from datetime import datetime

# preprocessing
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler, MinMaxScaler, PowerTransformer, QuantileTransformer

# validation
from sklearn.model_selection import KFold, StratifiedKFold, train_test_split, GridSearchCV, cross_val_score

# valuation
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# modeling
from sklearn.linear_model import LinearRegression, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# etc 
import warnings
warnings.filterwarnings(action='ignore')

# %%
# 데이터 불러오기
data = pd.read_csv("C:/Users/sssum/Downloads/insurance_dataset.csv/insurance_dataset.csv")
data.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46    male  21.45         5    yes  southeast        Diabetes
# 1   25  female  25.38         2    yes  northwest        Diabetes
# 2   38    male  44.88         2    yes  southwest            None
# 3   25    male  19.89         0     no  northwest            None
# 4   49    male  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history exercise_frequency    occupation coverage_level  \
# 0                   None              Never   Blue collar        Premium
# 1    High blood pressure       Occasionally  White collar        Premium
# 2    High blood pressure       Occasionally   Blue collar        Premium
# 3               Diabetes             Rarely  White collar       Standard
# 4    High blood pressure             Rarely  White collar       Standard
#
#         charges
# 0  20460.307669
# 1  20390.899218
# 2  20204.476302
# 3  11789.029843
# 4  19268.309838

# %%
# 데이터 기본 정보 확인
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   age                     1000000 non-null  int64
#  1   gender                  1000000 non-null  object
#  2   bmi                     1000000 non-null  float64
#  3   children                1000000 non-null  int64
#  4   smoker                  1000000 non-null  object
#  5   region                  1000000 non-null  object
#  6   medical_history         1000000 non-null  object
#  7   family_medical_history  1000000 non-null  object
#  8   exercise_frequency      1000000 non-null  object
#  9   occupation              1000000 non-null  object
#  10  coverage_level          1000000 non-null  object
#  11  charges                 1000000 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 91.6+ MB

# %%
# 데이터 통계정보 확인
data.describe()
# Out:
#                   age             bmi        children         charges
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean        41.495282       34.001839        2.499886    16735.117481
# std         13.855189        9.231680        1.707679     4415.808211
# min         18.000000       18.000000        0.000000     3445.011643
# 25%         29.000000       26.020000        1.000000    13600.372379
# 50%         41.000000       34.000000        2.000000    16622.127973
# 75%         53.000000       41.990000        4.000000    19781.465410
# max         65.000000       50.000000        5.000000    32561.560374

# %% [markdown]
# - 평균과 표준편차가 거의 비슷한 컬럼은 분포가 퍼져있을 확률이 높으므로 후에 분포를 모아주는 작업이 필요할 수 있음
# - 값 범위가 크게 다른 속성이 있으면 스케일링 작업이 필요함, 종속변수는 제외

# %% [markdown]
# ## EDA

# %%
# 속성 분포 확인
fig, ax = plt.subplots(5, 2, figsize=(30, 40))

idx = 0
for i in range(5): # subplot 행
    for j in range(2): # subplot 열
        colname = list(data.columns)[idx]
        ax[i][j].hist(data[colname], bins=20)
        ax[i][j].set_xlabel(colname)
        ax[i][j].set_ylabel('Frequency')
        
        idx += 1

# %% [markdown]
# 컬럼들의 값 분포를 보았을 때, 크게 치우친 부분 없이 고르게 분포되어 있음을 알 수 있음.

# %%
# 컬럼 간 상관관계 파악
data.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.001428 -0.001317  0.063390
# bmi       0.001428  1.000000 -0.001635  0.104429
# children -0.001317 -0.001635  1.000000  0.076801
# charges   0.063390  0.104429  0.076801  1.000000

# %%
# 연령별 구간 설정
bins = [0, 20, 25, 30, 35, 40, 45, 50, 55, 60, np.inf]
age_bin = pd.cut(data['age'], bins=bins, labels=[i+1 for i in range(len(bins)-1)])
data['age_bin'] = age_bin
data.head()
# Out:
#    age  gender    bmi  children smoker     region medical_history  \
# 0   46    male  21.45         5    yes  southeast        Diabetes
# 1   25  female  25.38         2    yes  northwest        Diabetes
# 2   38    male  44.88         2    yes  southwest            None
# 3   25    male  19.89         0     no  northwest            None
# 4   49    male  38.21         3    yes  northwest        Diabetes
#
#   family_medical_history exercise_frequency    occupation coverage_level  \
# 0                   None              Never   Blue collar        Premium
# 1    High blood pressure       Occasionally  White collar        Premium
# 2    High blood pressure       Occasionally   Blue collar        Premium
# 3               Diabetes             Rarely  White collar       Standard
# 4    High blood pressure             Rarely  White collar       Standard
#
#         charges age_bin
# 0  20460.307669       7
# 1  20390.899218       2
# 2  20204.476302       5
# 3  11789.029843       2
# 4  19268.309838       7

# %%
# 구간화 속성 분포 확인
data['age_bin'].value_counts()
# Out:
# 3     104522
# 10    104286
# 5     104221
# 6     104189
# 4     104138
# 7     104067
# 8     104041
# 9     103994
# 2     103797
# 1      62745
# Name: age_bin, dtype: int64

# %% [markdown]
# 구간화 작업
# - 참고한 예시에서 age 속성의 분포를 확인했을 때, 18-19세만 다른 나이대들의 2배였음.
# - 그래서 다른 나이대들은 5세로 분포를 넓히고, 18-19세는 분포를 좁혀 구간화를 진행함.
# - 이를 통해 위 결과처럼 다른 나이대분포가 더 많아졌음을 알 수 있음.
# - 구간화 작업은 불균형이 있는 속성의 분포를 조절하는 방식
# - 우리가 사용한 데이터는 나이대에 불균형이 없어서 진행하지 않아도 됨

# %%
# 이상치 탐지
plt.subplot(1, 3, 1)
sns.boxplot(data=data, y='age')
plt.subplot(1, 3, 2)
sns.boxplot(data=data, y='children')
plt.subplot(1, 3, 3)
sns.boxplot(data=data, y='bmi')
# Out:
# <Axes: ylabel='bmi'>

# %% [markdown]
# 이상치도 없음.

# %%
# 해당 문제는 이상치가 없지만, 이상치를 확인하는 방법 코드
# IQR: Inter Quantile Range, 사분위수 25%, 75% 사이인 
# Interquatile Range 범위에서 1.5를 곱해 각각 25% 사분위수와 
# 75% 사분위수를 더한 범위를 벗어난 값을 이상치로 보고 삭제하는 방식 
bmi_q1 = data['bmi'].quantile(q=0.25)
bmi_q3 = data['bmi'].quantile(q=0.75)
iqr = bmi_q3 - bmi_q1

condi1 = (data['bmi'] < (bmi_q1 - (1.5 * iqr)))
condi2 = (data['bmi'] > (bmi_q3 + (1.5 * iqr)))
outliers = data[condi1 | condi2]
outliers['bmi']
# Out:
# Series([], Name: bmi, dtype: float64)

# %% [markdown]
# ## 데이터 전처리
# - 정규화: 변수 범위를 0~1 사이로 옮기는 작업, MinMaxScaler
# - 표준화: 변수 범위 평균 0, 표준편차 1로 변환, StandardScaler

# %% [markdown]
# 정규변환 (정규분포에 가깝게 변수를 변환)
# - 필요한 경우: 정규성 분포를 따른다는 가정하에 모델링 해야하는 선형회귀, 가우시안 나이브 베이즈 모델을 사용하는 경우
# - 로그변환: 변수에 로그를 취해주면 정규분포의 형태와 가깝게 변환됨
# - Power Transformation: 특정 수식에 따른 변수 변환
# - Quantile Transformation: 미리 정한 분포에 따라 그에 상승하는 x값 반환

# %%
# 결측치 처리
# family_medical_history, medical_history 컬럼에 None으로 결측치 존재
# 결측치 비율이 25%
print(data['family_medical_history'].value_counts())
print(data['medical_history'].value_counts())
# Out:
# None                   250404
# Heart disease          250035
# High blood pressure    249824
# Diabetes               249737
# Name: family_medical_history, dtype: int64
# None                   250762
# Heart disease          250121
# High blood pressure    249782
# Diabetes               249335
# Name: medical_history, dtype: int64

# %%
# 결측치가 있는 컬럼의 다른 컬럼과의 관계 파악 - 나이
family_filter = data[data['family_medical_history'] == 'None']['age']
medical_filter = data[data['medical_history'] == 'None']['age']
print(family_filter.describe())
print(medical_filter.describe())
# Out:
# count    250404.000000
# mean         41.500851
# std          13.855506
# min          18.000000
# 25%          29.000000
# 50%          42.000000
# 75%          53.000000
# max          65.000000
# Name: age, dtype: float64
# count    250762.000000
# mean         41.485863
# std          13.845353
# min          18.000000
# 25%          30.000000
# 50%          41.000000
# 75%          53.000000
# max          65.000000
# Name: age, dtype: float64

# %%
# 결측치가 있는 컬럼의 다른 컬럼과의 관계 파악 - bmi
family_filter = data[data['family_medical_history'] == 'None']['bmi']
medical_filter = data[data['medical_history'] == 'None']['bmi']
print(family_filter.describe())
print(medical_filter.describe())
# Out:
# count    250404.000000
# mean         34.010019
# std           9.221582
# min          18.000000
# 25%          26.030000
# 50%          34.010000
# 75%          41.950000
# max          50.000000
# Name: bmi, dtype: float64
# count    250762.000000
# mean         34.018554
# std           9.229882
# min          18.000000
# 25%          26.040000
# 50%          34.050000
# 75%          41.990000
# max          50.000000
# Name: bmi, dtype: float64

# %%
# 결측치가 있는 컬럼의 다른 컬럼과의 관계 파악 - children
family_filter = data[data['family_medical_history'] == 'None']['children']
medical_filter = data[data['medical_history'] == 'None']['children']
print(family_filter.describe())
print(medical_filter.describe())
# Out:
# count    250404.000000
# mean          2.499493
# std           1.705744
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           4.000000
# max           5.000000
# Name: children, dtype: float64
# count    250762.000000
# mean          2.502118
# std           1.708984
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%           4.000000
# max           5.000000
# Name: children, dtype: float64

# %% [markdown]
# 결측치 행의 나이, bmi, 자녀 수 컬럼 값들은 고르게 분포되어있음.

# %%
# 결측치 행 데이터의 범주형 컬럼 값 분포 확인
None_data = data[(data['family_medical_history'] == 'None') & (data['medical_history'] == 'None')]
None_data.describe(include='object')
# Out:
#         gender smoker     region medical_history family_medical_history  \
# count    62838  62838      62838           62838                  62838
# unique       2      2          4               1                      1
# top     female    yes  southwest            None                   None
# freq     31536  31716      15899           62838                  62838
#
#        exercise_frequency  occupation coverage_level
# count               62838       62838          62838
# unique                  4           4              3
# top                Rarely  Unemployed          Basic
# freq                15862       15813          21017

# %% [markdown]
# 범주형 컬럼도 분포가 고르다고 판단함. 결측치는 None으로 저장하고 분석 진행함.

# %%
# 정규분포 확인
plt.figsize = (10, 10)
plt.hist(data['bmi'], bins=30)
plt.xlabel('bmi')
plt.ylabel('frequency')
plt.show()

# %%
# 로그 변환
to_scale = ['age', 'bmi', 'children', 'charges']
df_to_scale = data[to_scale].copy()

quantile = QuantileTransformer(n_quantiles=100, random_state=42, output_distribution='normal')
power = PowerTransformer(method='yeo-johnson')
q_scaled = quantile.fit_transform(df_to_scale)
yj = power.fit_transform(df_to_scale)

q_scaled_df = pd.DataFrame(q_scaled, columns=to_scale)
scaled_df = pd.DataFrame(yj, columns=to_scale)
logged_df = pd.DataFrame(np.log1p(df_to_scale), columns=to_scale)
# 로그 특성상 0보다 작은 값이 있는 속성에는 사용 불가

fig, ax = plt.subplots(4, 4, figsize=(40, 30))

for i in range(4):
    idx=0
    for j in range(4):
        colname = to_scale[idx]
        if i == 0:
            ax[i][j].hist(df_to_scale[colname], bins=30)
            ax[i][j].set_xlabel(colname)
            ax[i][j].set_ylabel('Frequency')
            
        elif i == 1:
            ax[i][j].hist(scaled_df[colname], bins=30)
            ax[i][j].set_xlabel(colname)
            ax[i][j].set_ylabel('Transformed Frequency')  
        elif i == 2:
            ax[i][j].hist(q_scaled_df[colname], bins=30)
            ax[i][j].set_xlabel(colname)
            ax[i][j].set_ylabel('Transformed Frequency')
        elif i == 3:
            ax[i][j].hist(logged_df[colname], bins=30)
            ax[i][j].set_xlabel(colname)
            ax[i][j].set_ylabel('Logged Frequency')
            
        idx +=1

# %%
# 데이터 분할
x = data.drop(['charges'], axis=1)
y = data['charges']

train_input, test_input, train_target, test_target = train_test_split(x, y, test_size=0.2, shuffle=True)

# %%
# Quantile Transformer 사용
to_scale = ['age', 'bmi']

quantile = QuantileTransformer(n_quantiles=10, random_state=42, output_distribution='normal')

for col in to_scale:
    quantile.fit(train_input[[col]]) # 2차원 데이터로 투입하기 위해 괄호 두 개 사용
    train_input[col] = quantile.transform(train_input[[col]]).flatten()
    test_input[col] = quantile.transform(test_input[[col]]).flatten()

# %%
# 결과 확인
print(train_input.head())
print('-----------------')
print(test_input.head())
# Out:
#              age  gender       bmi  children smoker     region  \
# 918171  0.234219  female  0.199243         4    yes  southwest
# 975088  0.139710  female -0.065929         4     no  northeast
# 208059  1.012893    male  0.758401         4    yes  northeast
# 254238  0.027855    male  1.126909         1    yes  southwest
# 732281 -1.012893    male -0.905560         3     no  southwest
#
#             medical_history family_medical_history exercise_frequency  \
# 918171        Heart disease                   None              Never
# 975088        Heart disease               Diabetes       Occasionally
# 208059  High blood pressure                   None             Rarely
# 254238  High blood pressure          Heart disease       Occasionally
# 732281        Heart disease               Diabetes             Rarely
#
#          occupation coverage_level
# 918171  Blue collar       Standard
# 975088      Student        Premium
# 208059   Unemployed        Premium
# 254238  Blue collar       Standard
# 732281  Blue collar       Standard
# -----------------
#              age  gender       bmi  children smoker     region  \
# 460842 -0.027855    male -0.009863         4    yes  northwest
# 442364  1.701288    male -1.305504         5    yes  northwest
# 783249 -0.370364  female  0.413622         0    yes  southwest
# 614994  0.083652  female  1.278042         0    yes  southwest
# 863913  1.220640  female -0.701558         3     no  northeast
#
#             medical_history family_medical_history exercise_frequency  \
# 460842                 None               Diabetes              Never
# 442364                 None          Heart disease             Rarely
# 783249  High blood pressure    High blood pressure              Never
# 614994             Diabetes                   None              Never
# 863913                 None          Heart disease       Occasionally
#
#           occupation coverage_level
# 460842  White collar        Premium
# 442364       Student          Basic
# 783249   Blue collar          Basic
# 614994   Blue collar        Premium
# 863913       Student        Premium

# %%
# 표준화 진행
cols = ['age', 'bmi', 'children']
for col in cols:
    std = StandardScaler()
    std.fit(train_input[[col]])
    train_input[col] = std.transform(train_input[[col]]).flatten()
    test_input[col] = std.transform(test_input[[col]]).flatten()
    
train_input.describe()
# Out:
#                 age           bmi      children
# count  8.000000e+05  8.000000e+05  8.000000e+05
# mean   7.878143e-18  1.765699e-17 -7.061907e-17
# std    1.000001e+00  1.000001e+00  1.000001e+00
# min   -3.745486e+00 -5.184883e+00 -1.464110e+00
# 25%   -4.604557e-01 -6.733044e-01 -8.785505e-01
# 50%    2.539500e-02 -1.536747e-03  2.925691e-01
# 75%    4.546773e-01  6.728979e-01  8.781289e-01
# max    3.756087e+00  5.181024e+00  1.463689e+00

# %%
# 범주형 변수 처리 - gender
onehot_gender = OneHotEncoder()
gender_train = train_input[['gender']]
gender_test = test_input[['gender']]

onehot_gender.fit(gender_train)
gender_train_onehot_gender = onehot_gender.transform(gender_train).toarray()
gender_test_onehot_gender = onehot_gender.transform(gender_test).toarray()

train_input['gender'] = gender_train_onehot_gender[:, 1].astype(np.uint8)
test_input['gender'] = gender_test_onehot_gender[:, 1].astype(np.uint8)

train_input.head()
# Out:
#              age  gender       bmi  children smoker     region  \
# 918171  0.174266       0  0.196685  0.878129    yes  southwest
# 975088  0.106087       0 -0.067651  0.878129     no  northeast
# 208059  0.735999       1  0.754081  0.878129    yes  northeast
# 254238  0.025395       1  1.121428 -0.878550    yes  southwest
# 732281 -0.725398       1 -0.904637  0.292569     no  southwest
#
#             medical_history family_medical_history exercise_frequency  \
# 918171        Heart disease                   None              Never
# 975088        Heart disease               Diabetes       Occasionally
# 208059  High blood pressure                   None             Rarely
# 254238  High blood pressure          Heart disease       Occasionally
# 732281        Heart disease               Diabetes             Rarely
#
#          occupation coverage_level
# 918171  Blue collar       Standard
# 975088      Student        Premium
# 208059   Unemployed        Premium
# 254238  Blue collar       Standard
# 732281  Blue collar       Standard

# %%
# 범주형 변수 처리 - smoker
onehot_smoker = OneHotEncoder()
smoker_train = train_input[['smoker']]
smoker_test = test_input[['smoker']]

onehot_smoker.fit(smoker_train)
smoker_train_onehot = onehot_smoker.transform(smoker_train).toarray()
smoker_test_onehot = onehot_smoker.transform(smoker_test).toarray()

train_input['smoker'] = smoker_train_onehot[:, 1].astype(np.uint8)
test_input['smoker'] = smoker_test_onehot[:, 1].astype(np.uint8)

train_input.head()
# Out:
#              age  gender       bmi  children  smoker     region  \
# 918171  0.174266       0  0.196685  0.878129       1  southwest
# 975088  0.106087       0 -0.067651  0.878129       0  northeast
# 208059  0.735999       1  0.754081  0.878129       1  northeast
# 254238  0.025395       1  1.121428 -0.878550       1  southwest
# 732281 -0.725398       1 -0.904637  0.292569       0  southwest
#
#             medical_history family_medical_history exercise_frequency  \
# 918171        Heart disease                   None              Never
# 975088        Heart disease               Diabetes       Occasionally
# 208059  High blood pressure                   None             Rarely
# 254238  High blood pressure          Heart disease       Occasionally
# 732281        Heart disease               Diabetes             Rarely
#
#          occupation coverage_level
# 918171  Blue collar       Standard
# 975088      Student        Premium
# 208059   Unemployed        Premium
# 254238  Blue collar       Standard
# 732281  Blue collar       Standard

# %%
# 먼저 라벨 인코더를 사용하여 거주지역을 숫자형으로 바꾸기
label_region = LabelEncoder()
label_region.fit(train_input['region'])

train_input['region'] = label_region.transform(train_input['region'])
test_input['region'] = label_region.transform(test_input['region'])

train_input.head()
# Out:
#              age  gender       bmi  children  smoker  region  \
# 918171  0.174266       0  0.196685  0.878129       1       3
# 975088  0.106087       0 -0.067651  0.878129       0       0
# 208059  0.735999       1  0.754081  0.878129       1       0
# 254238  0.025395       1  1.121428 -0.878550       1       3
# 732281 -0.725398       1 -0.904637  0.292569       0       3
#
#             medical_history family_medical_history exercise_frequency  \
# 918171        Heart disease                   None              Never
# 975088        Heart disease               Diabetes       Occasionally
# 208059  High blood pressure                   None             Rarely
# 254238  High blood pressure          Heart disease       Occasionally
# 732281        Heart disease               Diabetes             Rarely
#
#          occupation coverage_level
# 918171  Blue collar       Standard
# 975088      Student        Premium
# 208059   Unemployed        Premium
# 254238  Blue collar       Standard
# 732281  Blue collar       Standard

# %%
# one-hot encoding으로 거주지역 바꾸기
onehot_region = OneHotEncoder()
region_train = train_input[['region']]
region_test = test_input[['region']]

onehot_region.fit(region_train)
region_train_onehot = onehot_region.transform(region_train).toarray()
region_test_onehot = onehot_region.transform(region_test).toarray()

train_input['region_1'] = region_train_onehot[:, 1].astype(np.uint8)
train_input['region_2'] = region_train_onehot[:, 2].astype(np.uint8)
train_input['region_3'] = region_train_onehot[:, 3].astype(np.uint8)


test_input['region_1'] = region_test_onehot[:, 1].astype(np.uint8)
test_input['region_2'] = region_test_onehot[:, 2].astype(np.uint8)
test_input['region_3'] = region_test_onehot[:, 3].astype(np.uint8)

train_input.drop(['region'], axis=1, inplace=True)
test_input.drop(['region'], axis=1, inplace=True)

# %%
# 결과 확인
train_input.head()
# Out:
#              age  gender       bmi  children  smoker      medical_history  \
# 918171  0.174266       0  0.196685  0.878129       1        Heart disease
# 975088  0.106087       0 -0.067651  0.878129       0        Heart disease
# 208059  0.735999       1  0.754081  0.878129       1  High blood pressure
# 254238  0.025395       1  1.121428 -0.878550       1  High blood pressure
# 732281 -0.725398       1 -0.904637  0.292569       0        Heart disease
#
#        family_medical_history exercise_frequency   occupation coverage_level  \
# 918171                   None              Never  Blue collar       Standard
# 975088               Diabetes       Occasionally      Student        Premium
# 208059                   None             Rarely   Unemployed        Premium
# 254238          Heart disease       Occasionally  Blue collar       Standard
# 732281               Diabetes             Rarely  Blue collar       Standard
#
#         region_1  region_2  region_3
# 918171         0         0         1
# 975088         0         0         0
# 208059         0         0         0
# 254238         0         0         1
# 732281         0         0         1

# %%
# 그 외 범주형 변수 모두 변형
# medical_history
label_medical = LabelEncoder()
label_medical.fit(train_input['medical_history'])

train_input['medical_history'] = label_medical.transform(train_input['medical_history'])
test_input['medical_history'] = label_medical.transform(test_input['medical_history'])

train_input.head()

onehot_medical = OneHotEncoder()
medical_train = train_input[['medical_history']]
medical_test = test_input[['medical_history']]

onehot_medical.fit(medical_train)
medical_train_onehot = onehot_medical.transform(medical_train).toarray()
medical_test_onehot = onehot_medical.transform(medical_test).toarray()

train_input['medical_1'] = medical_train_onehot[:, 1].astype(np.uint8)
train_input['medical_2'] = medical_train_onehot[:, 2].astype(np.uint8)
train_input['medical_3'] = medical_train_onehot[:, 3].astype(np.uint8)


test_input['medical_1'] = medical_test_onehot[:, 1].astype(np.uint8)
test_input['medical_2'] = medical_test_onehot[:, 2].astype(np.uint8)
test_input['medical_3'] = medical_test_onehot[:, 3].astype(np.uint8)

train_input.drop(['medical_history'], axis=1, inplace=True)
test_input.drop(['medical_history'], axis=1, inplace=True)

# %%
# 그 외 범주형 변수 모두 변형
# family_medical_history
label_family = LabelEncoder()
label_family.fit(train_input['family_medical_history'])

train_input['family_medical_history'] = label_family.transform(train_input['family_medical_history'])
test_input['family_medical_history'] = label_family.transform(test_input['family_medical_history'])

train_input.head()

onehot_family = OneHotEncoder()
family_train = train_input[['family_medical_history']]
family_test = test_input[['family_medical_history']]

onehot_family.fit(family_train)
family_train_onehot = onehot_family.transform(family_train).toarray()
family_test_onehot = onehot_family.transform(family_test).toarray()

train_input['family_1'] = family_train_onehot[:, 1].astype(np.uint8)
train_input['family_2'] = family_train_onehot[:, 2].astype(np.uint8)
train_input['family_3'] = family_train_onehot[:, 3].astype(np.uint8)


test_input['family_1'] = family_test_onehot[:, 1].astype(np.uint8)
test_input['family_2'] = family_test_onehot[:, 2].astype(np.uint8)
test_input['family_3'] = family_test_onehot[:, 3].astype(np.uint8)

train_input.drop(['family_medical_history'], axis=1, inplace=True)
test_input.drop(['family_medical_history'], axis=1, inplace=True)

# %%
# 그 외 범주형 변수 모두 변형
# exercise_frequency
label_exercise = LabelEncoder()
label_exercise.fit(train_input['exercise_frequency'])

train_input['exercise_frequency'] = label_exercise.transform(train_input['exercise_frequency'])
test_input['exercise_frequency'] = label_exercise.transform(test_input['exercise_frequency'])

train_input.head()

onehot_exercise = OneHotEncoder()
exercise_train = train_input[['exercise_frequency']]
exercise_test = test_input[['exercise_frequency']]

onehot_exercise.fit(exercise_train)
exercise_train_onehot = onehot_exercise.transform(exercise_train).toarray()
exercise_test_onehot = onehot_exercise.transform(exercise_test).toarray()

train_input['exercise_1'] = exercise_train_onehot[:, 1].astype(np.uint8)
train_input['exercise_2'] = exercise_train_onehot[:, 2].astype(np.uint8)
train_input['exercise_3'] = exercise_train_onehot[:, 3].astype(np.uint8)


test_input['exercise_1'] = exercise_test_onehot[:, 1].astype(np.uint8)
test_input['exercise_2'] = exercise_test_onehot[:, 2].astype(np.uint8)
test_input['exercise_3'] = exercise_test_onehot[:, 3].astype(np.uint8)

train_input.drop(['exercise_frequency'], axis=1, inplace=True)
test_input.drop(['exercise_frequency'], axis=1, inplace=True)

# %%
train_input.head()
# Out:
#              age  gender       bmi  children  smoker   occupation  \
# 918171  0.174266       0  0.196685  0.878129       1  Blue collar
# 975088  0.106087       0 -0.067651  0.878129       0      Student
# 208059  0.735999       1  0.754081  0.878129       1   Unemployed
# 254238  0.025395       1  1.121428 -0.878550       1  Blue collar
# 732281 -0.725398       1 -0.904637  0.292569       0  Blue collar
#
#        coverage_level  region_1  region_2  region_3  medical_1  medical_2  \
# 918171       Standard         0         0         1          1          0
# 975088        Premium         0         0         0          1          0
# 208059        Premium         0         0         0          0          1
# 254238       Standard         0         0         1          0          1
# 732281       Standard         0         0         1          1          0
#
#         medical_3  family_1  family_2  family_3  exercise_1  exercise_2  \
# 918171          0         0         0         1           1           0
# 975088          0         0         0         0           0           1
# 208059          0         0         0         1           0           0
# 254238          0         1         0         0           0           1
# 732281          0         0         0         0           0           0
#
#         exercise_3
# 918171           0
# 975088           0
# 208059           1
# 254238           0
# 732281           1

# %%
# 그 외 범주형 변수 모두 변형
# occupation
label_occupation = LabelEncoder()
label_occupation.fit(train_input['occupation'])

train_input['occupation'] = label_occupation.transform(train_input['occupation'])
test_input['occupation'] = label_occupation.transform(test_input['occupation'])

train_input.head()

onehot_occupation = OneHotEncoder()
occupation_train = train_input[['occupation']]
occupation_test = test_input[['occupation']]

onehot_occupation.fit(occupation_train)
occupation_train_onehot = onehot_occupation.transform(occupation_train).toarray()
occupation_test_onehot = onehot_occupation.transform(occupation_test).toarray()

train_input['occupation_1'] = occupation_train_onehot[:, 1].astype(np.uint8)
train_input['occupation_2'] = occupation_train_onehot[:, 2].astype(np.uint8)
train_input['occupation_3'] = occupation_train_onehot[:, 3].astype(np.uint8)


test_input['occupation_1'] = occupation_test_onehot[:, 1].astype(np.uint8)
test_input['occupation_2'] = occupation_test_onehot[:, 2].astype(np.uint8)
test_input['occupation_3'] = occupation_test_onehot[:, 3].astype(np.uint8)

train_input.drop(['occupation'], axis=1, inplace=True)
test_input.drop(['occupation'], axis=1, inplace=True)

# %%
# 그 외 범주형 변수 모두 변형
# coverage_level
label_level = LabelEncoder()
label_level.fit(train_input['coverage_level'])

train_input['coverage_level'] = label_level.transform(train_input['coverage_level'])
test_input['coverage_level'] = label_level.transform(test_input['coverage_level'])

train_input.head()

onehot_level = OneHotEncoder()
level_train = train_input[['coverage_level']]
level_test = test_input[['coverage_level']]

onehot_level.fit(level_train)
level_train_onehot = onehot_level.transform(level_train).toarray()
level_test_onehot = onehot_level.transform(level_test).toarray()

train_input['level_1'] = level_train_onehot[:, 1].astype(np.uint8)
train_input['level_2'] = level_train_onehot[:, 2].astype(np.uint8)


test_input['level_1'] = level_test_onehot[:, 1].astype(np.uint8)
test_input['level_2'] = level_test_onehot[:, 2].astype(np.uint8)

train_input.drop(['coverage_level'], axis=1, inplace=True)
test_input.drop(['coverage_level'], axis=1, inplace=True)

# %%
# 결과 확인
train_input.head()
# Out:
#              age  gender       bmi  children  smoker  region_1  region_2  \
# 918171  0.174266       0  0.196685  0.878129       1         0         0
# 975088  0.106087       0 -0.067651  0.878129       0         0         0
# 208059  0.735999       1  0.754081  0.878129       1         0         0
# 254238  0.025395       1  1.121428 -0.878550       1         0         0
# 732281 -0.725398       1 -0.904637  0.292569       0         0         0
#
#         region_3  medical_1  medical_2  ...  family_2  family_3  exercise_1  \
# 918171         1          1          0  ...         0         1           1
# 975088         0          1          0  ...         0         0           0
# 208059         0          0          1  ...         0         1           0
# 254238         1          0          1  ...         0         0           0
# 732281         1          1          0  ...         0         0           0
#
#         exercise_2  exercise_3  occupation_1  occupation_2  occupation_3  \
# 918171           0           0             0             0             0
# 975088           1           0             1             0             0
# 208059           0           1             0             1             0
# 254238           1           0             0             0             0
# 732281           0           1             0             0             0
#
#         level_1  level_2
# 918171        0        1
# 975088        1        0
# 208059        1        0
# 254238        0        1
# 732281        0        1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 모델링
# - linear model: Linear Regression, Elastic Net (Ridge, Lasso 회귀 방식을 합쳐놓은 형태)
# - Decision Tree
# - Ensemble: Random Forest, AdaBoost, Gradient Boosting
# - Boosting: XGBoost, LightGBM, CatBoost

# %%
# 데이터 확인
print(train_input.shape, train_target.shape)
print(test_input.shape, test_target.shape)
# Out:
# (800000, 22) (800000,)
# (200000, 22) (200000,)

# %%
# 모델 객체 생성
cat_list = []
lr = LinearRegression()
enet = ElasticNet(random_state=42)
dt = DecisionTreeRegressor(random_state=42)
rf = RandomForestRegressor(random_state=42)
ada = AdaBoostRegressor(random_state=42)
gbr = GradientBoostingRegressor(random_state=42)
xgb = XGBRegressor(random_state=42)
lgbm = LGBMRegressor(random_state=42)
cat = CatBoostRegressor(random_state=42)

models = [lr, enet, dt, rf, ada, gbr, xgb, lgbm, cat]

# %%
# 모델 rmse, mae 값 확인
for model in models:
    name = model.__class__.__name__
    mse_scores = cross_val_score(model, X=train_input, y=train_target, cv=5,
                             scoring='neg_mean_squared_error', n_jobs=-1)
    mae_scores = cross_val_score(model, X=train_input, y=train_target, cv=5,
                             scoring='neg_mean_absolute_error', n_jobs=-1)
    rmse = np.sqrt((-1) * np.mean(mse_scores))
    mae = (-1) * np.mean(mae_scores)
    print('Model %s - RMSE: %.4f, MAE: %.4f' % (name, rmse, mae))
# Out:
# Model LinearRegression - RMSE: 336.7916, MAE: 279.5697
# Model ElasticNet - RMSE: 3049.3483, MAE: 2473.5580
# Model DecisionTreeRegressor - RMSE: 586.5878, MAE: 468.0287
# Model RandomForestRegressor - RMSE: 421.0840, MAE: 341.5024
# Model AdaBoostRegressor - RMSE: 1489.5627, MAE: 1197.2036
# Model GradientBoostingRegressor - RMSE: 575.4874, MAE: 461.1942
# Model XGBRegressor - RMSE: 335.0523, MAE: 278.9925
# Model LGBMRegressor - RMSE: 328.9857, MAE: 274.8666
# Model CatBoostRegressor - RMSE: 289.1520, MAE: 250.3980

# %% [markdown]
# ## 하이퍼 파라미터 튜닝
# - 성능이 가장 좋은 모델 4개를 가지고 성능 향상
# - CatBoostRegressor, LGBMRegressor, XGBRegressor, LinearRegression
# - LinearRegression은 튜닝 안함

# %%
train_input.columns
# Out:
# Index(['age', 'gender', 'bmi', 'children', 'smoker', 'region_1', 'region_2',
#        'region_3', 'medical_1', 'medical_2', 'medical_3', 'family_1',
#        'family_2', 'family_3', 'exercise_1', 'exercise_2', 'exercise_3',
#        'occupation_1', 'occupation_2', 'occupation_3', 'level_1', 'level_2'],
#       dtype='object')

# %%
# CatBoostRegressor 하이퍼 파라미터 튜닝
cat_features = ['gender', 'smoker', 'region_1', 'region_2',
       'region_3', 'medical_1', 'medical_2', 'medical_3', 'family_1',
       'family_2', 'family_3', 'exercise_1', 'exercise_2', 'exercise_3',
       'occupation_1', 'occupation_2', 'occupation_3', 'level_1', 'level_2']

cat_params = {
    'learning_rate': [0.01, 0.05, 0.1, 0.5],
    'n_estimators': [100, 300, 500, 700],
    'max_depth': [3, 7, 11],
    'cat_features': [cat_features],
    'random_state': [42]
}

cat_search = GridSearchCV(cat, param_grid=cat_params, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
cat_search.fit(train_input, train_target)
best_mse = (-1) * cat_search.best_score_ # scoring 지표로 선택한 neg_mean_squared_error 값이 음수 부호가 붙은 mse 
best_rmse = np.sqrt(best_mse) # mse 값에 루트
# Out:
# 0:	learn: 3143.9213705	total: 157ms	remaining: 46.9s
# 1:	learn: 2406.8297004	total: 171ms	remaining: 25.4s
# 2:	learn: 2093.2344244	total: 183ms	remaining: 18.1s
# 3:	learn: 1856.7441227	total: 195ms	remaining: 14.4s
# 4:	learn: 1702.3944564	total: 207ms	remaining: 12.2s
# 5:	learn: 1444.4374803	total: 221ms	remaining: 10.8s
# 6:	learn: 1331.5272955	total: 237ms	remaining: 9.93s
# 7:	learn: 1244.3408249	total: 251ms	remaining: 9.17s
# 8:	learn: 1132.1392815	total: 265ms	remaining: 8.56s
# 9:	learn: 1046.3407633	total: 278ms	remaining: 8.06s
# 10:	learn: 950.7519846	total: 290ms	remaining: 7.61s
# 11:	learn: 878.6522763	total: 303ms	remaining: 7.26s
# 12:	learn: 783.0870907	total: 315ms	remaining: 6.95s
# 13:	learn: 735.6782154	total: 326ms	remaining: 6.66s
# 14:	learn: 695.7220242	total: 337ms	remaining: 6.4s
# 15:	learn: 646.2619676	total: 349ms	remaining: 6.19s
# 16:	learn: 606.8122898	total: 363ms	remaining: 6.04s
# 17:	learn: 570.3282343	total: 377ms	remaining: 5.91s
# 18:	learn: 537.1676856	total: 392ms	remaining: 5.8s
# 19:	learn: 499.8057458	total: 407ms	remaining: 5.7s
# 20:	learn: 474.6521065	total: 419ms	remaining: 5.57s
# 21:	learn: 455.4735908	total: 432ms	remaining: 5.46s
# 22:	learn: 440.2142600	total: 453ms	remaining: 5.45s
# 23:	learn: 426.1116883	total: 471ms	remaining: 5.42s
# 24:	learn: 412.8827564	total: 490ms	remaining: 5.39s
# 25:	learn: 401.2061118	total: 505ms	remaining: 5.32s
# 26:	learn: 392.6554151	total: 517ms	remaining: 5.23s
# 27:	learn: 385.6174540	total: 529ms	remaining: 5.14s
# 28:	learn: 378.2715345	total: 543ms	remaining: 5.08s
# 29:	learn: 367.7653493	total: 557ms	remaining: 5.01s
# 30:	learn: 357.3399843	total: 571ms	remaining: 4.95s
# 31:	learn: 343.8345259	total: 585ms	remaining: 4.9s
# 32:	learn: 337.3735684	total: 599ms	remaining: 4.84s
# 33:	learn: 332.1645501	total: 611ms	remaining: 4.78s
# 34:	learn: 328.6698224	total: 623ms	remaining: 4.71s
# 35:	learn: 325.8598909	total: 636ms	remaining: 4.66s
# 36:	learn: 323.7830599	total: 649ms	remaining: 4.62s
# 37:	learn: 320.7458092	total: 662ms	remaining: 4.56s
# 38:	learn: 317.0212803	total: 675ms	remaining: 4.52s
# 39:	learn: 314.0248836	total: 688ms	remaining: 4.47s
# 40:	learn: 312.2862799	total: 701ms	remaining: 4.43s
# 41:	learn: 311.0278287	total: 714ms	remaining: 4.38s
# 42:	learn: 308.6653777	total: 727ms	remaining: 4.35s
# 43:	learn: 306.8361592	total: 740ms	remaining: 4.31s
# 44:	learn: 305.6986592	total: 754ms	remaining: 4.27s
# 45:	learn: 304.1425577	total: 768ms	remaining: 4.24s
# 46:	learn: 303.4513889	total: 782ms	remaining: 4.21s
# 47:	learn: 302.6438836	total: 798ms	remaining: 4.19s
# 48:	learn: 302.1060698	total: 812ms	remaining: 4.16s
# 49:	learn: 301.5616356	total: 826ms	remaining: 4.13s
# 50:	learn: 301.1147410	total: 840ms	remaining: 4.1s
# 51:	learn: 300.6930786	total: 853ms	remaining: 4.07s
# 52:	learn: 299.5483714	total: 867ms	remaining: 4.04s
# 53:	learn: 299.0072765	total: 882ms	remaining: 4.02s
# 54:	learn: 298.6862119	total: 895ms	remaining: 3.99s
# 55:	learn: 297.6553121	total: 909ms	remaining: 3.96s
# 56:	learn: 296.4293932	total: 924ms	remaining: 3.94s
# 57:	learn: 296.1428728	total: 938ms	remaining: 3.92s
# 58:	learn: 295.5860108	total: 952ms	remaining: 3.89s
# 59:	learn: 295.1550520	total: 966ms	remaining: 3.86s
# 60:	learn: 294.7880282	total: 981ms	remaining: 3.84s
# 61:	learn: 294.3996797	total: 996ms	remaining: 3.82s
# 62:	learn: 294.2568723	total: 1.01s	remaining: 3.8s
# 63:	learn: 293.7992740	total: 1.03s	remaining: 3.79s
# 64:	learn: 293.6859116	total: 1.04s	remaining: 3.77s
# 65:	learn: 293.5817574	total: 1.06s	remaining: 3.75s
# 66:	learn: 293.1062031	total: 1.07s	remaining: 3.73s
# 67:	learn: 292.7193359	total: 1.09s	remaining: 3.72s
# 68:	learn: 292.2935017	total: 1.1s	remaining: 3.7s
# 69:	learn: 292.1560058	total: 1.12s	remaining: 3.68s
# 70:	learn: 292.0833803	total: 1.13s	remaining: 3.66s
# 71:	learn: 291.8491472	total: 1.15s	remaining: 3.64s
# 72:	learn: 291.7697104	total: 1.16s	remaining: 3.62s
# 73:	learn: 291.7055426	total: 1.18s	remaining: 3.6s
# 74:	learn: 291.5545343	total: 1.19s	remaining: 3.58s
# 75:	learn: 291.4118901	total: 1.21s	remaining: 3.56s
# 76:	learn: 291.2991476	total: 1.22s	remaining: 3.54s
# 77:	learn: 291.1886270	total: 1.24s	remaining: 3.52s
# 78:	learn: 291.0481909	total: 1.25s	remaining: 3.51s
# 79:	learn: 290.9039809	total: 1.27s	remaining: 3.49s
# 80:	learn: 290.7908454	total: 1.28s	remaining: 3.47s
# 81:	learn: 290.7495231	total: 1.29s	remaining: 3.44s
# 82:	learn: 290.7078917	total: 1.31s	remaining: 3.42s
# 83:	learn: 290.6793165	total: 1.32s	remaining: 3.4s
# 84:	learn: 290.6182980	total: 1.34s	remaining: 3.38s
# 85:	learn: 290.4772801	total: 1.35s	remaining: 3.37s
# 86:	learn: 290.3864565	total: 1.37s	remaining: 3.35s
# 87:	learn: 290.2939668	total: 1.38s	remaining: 3.33s
# 88:	learn: 290.2240725	total: 1.4s	remaining: 3.31s
# 89:	learn: 290.1374997	total: 1.41s	remaining: 3.29s
# 90:	learn: 290.0908121	total: 1.43s	remaining: 3.28s
# 91:	learn: 289.9776988	total: 1.44s	remaining: 3.26s
# 92:	learn: 289.9377196	total: 1.46s	remaining: 3.24s
# 93:	learn: 289.9184668	total: 1.47s	remaining: 3.22s
# 94:	learn: 289.8933673	total: 1.49s	remaining: 3.21s
# 95:	learn: 289.8598089	total: 1.5s	remaining: 3.19s
# 96:	learn: 289.8184013	total: 1.52s	remaining: 3.17s
# 97:	learn: 289.7678365	total: 1.53s	remaining: 3.15s
# 98:	learn: 289.7396898	total: 1.54s	remaining: 3.14s
# 99:	learn: 289.7148407	total: 1.56s	remaining: 3.12s
# 100:	learn: 289.6348543	total: 1.57s	remaining: 3.1s
# 101:	learn: 289.5947206	total: 1.59s	remaining: 3.09s
# 102:	learn: 289.5464845	total: 1.6s	remaining: 3.07s
# 103:	learn: 289.4777888	total: 1.62s	remaining: 3.05s
# 104:	learn: 289.4676719	total: 1.63s	remaining: 3.03s
# 105:	learn: 289.4363429	total: 1.65s	remaining: 3.02s
# 106:	learn: 289.4071162	total: 1.66s	remaining: 3s
# 107:	learn: 289.3912533	total: 1.68s	remaining: 2.99s
# 108:	learn: 289.3581695	total: 1.7s	remaining: 2.98s
# 109:	learn: 289.3285794	total: 1.72s	remaining: 2.96s
# 110:	learn: 289.3133370	total: 1.73s	remaining: 2.95s
# 111:	learn: 289.2692916	total: 1.74s	remaining: 2.93s
# 112:	learn: 289.2494424	total: 1.76s	remaining: 2.91s
# 113:	learn: 289.2302954	total: 1.77s	remaining: 2.89s
# 114:	learn: 289.2242420	total: 1.78s	remaining: 2.87s
# 115:	learn: 289.2129108	total: 1.8s	remaining: 2.85s
# 116:	learn: 289.1969569	total: 1.81s	remaining: 2.84s
# 117:	learn: 289.1882461	total: 1.83s	remaining: 2.82s
# 118:	learn: 289.1725821	total: 1.84s	remaining: 2.8s
# 119:	learn: 289.1676061	total: 1.86s	remaining: 2.78s
# 120:	learn: 289.1607075	total: 1.87s	remaining: 2.77s
# 121:	learn: 289.1536548	total: 1.89s	remaining: 2.75s
# 122:	learn: 289.1375772	total: 1.9s	remaining: 2.73s
# 123:	learn: 289.1281108	total: 1.91s	remaining: 2.72s
# 124:	learn: 289.1181038	total: 1.93s	remaining: 2.7s
# 125:	learn: 289.1072720	total: 1.94s	remaining: 2.68s
# 126:	learn: 289.0858981	total: 1.96s	remaining: 2.67s
# 127:	learn: 289.0507652	total: 1.97s	remaining: 2.65s
# 128:	learn: 289.0445899	total: 1.99s	remaining: 2.63s
# 129:	learn: 289.0399704	total: 2s	remaining: 2.62s
# 130:	learn: 289.0249788	total: 2.02s	remaining: 2.6s
# 131:	learn: 289.0109388	total: 2.03s	remaining: 2.58s
# 132:	learn: 288.9953075	total: 2.04s	remaining: 2.57s
# 133:	learn: 288.9903560	total: 2.06s	remaining: 2.55s
# 134:	learn: 288.9812056	total: 2.07s	remaining: 2.53s
# 135:	learn: 288.9608124	total: 2.09s	remaining: 2.52s
# 136:	learn: 288.9567999	total: 2.1s	remaining: 2.5s
# 137:	learn: 288.9476828	total: 2.12s	remaining: 2.48s
# 138:	learn: 288.9434116	total: 2.13s	remaining: 2.47s
# 139:	learn: 288.9374233	total: 2.14s	remaining: 2.45s
# 140:	learn: 288.9291901	total: 2.16s	remaining: 2.43s
# 141:	learn: 288.9235691	total: 2.17s	remaining: 2.42s
# 142:	learn: 288.9182556	total: 2.19s	remaining: 2.4s
# 143:	learn: 288.9050019	total: 2.2s	remaining: 2.38s
# 144:	learn: 288.8997392	total: 2.21s	remaining: 2.37s
# 145:	learn: 288.8938159	total: 2.23s	remaining: 2.35s
# 146:	learn: 288.8888698	total: 2.24s	remaining: 2.33s
# 147:	learn: 288.8836881	total: 2.26s	remaining: 2.32s
# 148:	learn: 288.8806772	total: 2.27s	remaining: 2.3s
# 149:	learn: 288.8751320	total: 2.28s	remaining: 2.28s
# 150:	learn: 288.8708095	total: 2.3s	remaining: 2.27s
# 151:	learn: 288.8661584	total: 2.31s	remaining: 2.25s
# 152:	learn: 288.8576497	total: 2.33s	remaining: 2.23s
# 153:	learn: 288.8540152	total: 2.34s	remaining: 2.22s
# 154:	learn: 288.8482000	total: 2.35s	remaining: 2.2s
# 155:	learn: 288.8447447	total: 2.37s	remaining: 2.19s
# 156:	learn: 288.8336972	total: 2.38s	remaining: 2.17s
# 157:	learn: 288.8207803	total: 2.4s	remaining: 2.15s
# 158:	learn: 288.8150032	total: 2.41s	remaining: 2.14s
# 159:	learn: 288.8067093	total: 2.42s	remaining: 2.12s
# 160:	learn: 288.8006982	total: 2.44s	remaining: 2.11s
# 161:	learn: 288.7974003	total: 2.46s	remaining: 2.09s
# 162:	learn: 288.7932956	total: 2.47s	remaining: 2.08s
# 163:	learn: 288.7890087	total: 2.48s	remaining: 2.06s
# 164:	learn: 288.7844718	total: 2.5s	remaining: 2.04s
# 165:	learn: 288.7818832	total: 2.52s	remaining: 2.03s
# 166:	learn: 288.7753604	total: 2.53s	remaining: 2.02s
# 167:	learn: 288.7717878	total: 2.54s	remaining: 2s
# 168:	learn: 288.7654738	total: 2.56s	remaining: 1.98s
# 169:	learn: 288.7626351	total: 2.57s	remaining: 1.97s
# 170:	learn: 288.7605972	total: 2.59s	remaining: 1.95s
# 171:	learn: 288.7579129	total: 2.6s	remaining: 1.94s
# 172:	learn: 288.7539321	total: 2.62s	remaining: 1.92s
# 173:	learn: 288.7502327	total: 2.63s	remaining: 1.9s
# 174:	learn: 288.7470608	total: 2.64s	remaining: 1.89s
# 175:	learn: 288.7442082	total: 2.66s	remaining: 1.87s
# 176:	learn: 288.7412549	total: 2.67s	remaining: 1.86s
# 177:	learn: 288.7377642	total: 2.69s	remaining: 1.84s
# 178:	learn: 288.7350442	total: 2.7s	remaining: 1.83s
# 179:	learn: 288.7305865	total: 2.72s	remaining: 1.81s
# 180:	learn: 288.7256953	total: 2.73s	remaining: 1.8s
# 181:	learn: 288.7214552	total: 2.75s	remaining: 1.78s
# 182:	learn: 288.7160427	total: 2.76s	remaining: 1.77s
# 183:	learn: 288.7125746	total: 2.78s	remaining: 1.75s
# 184:	learn: 288.7097159	total: 2.79s	remaining: 1.74s
# 185:	learn: 288.7072093	total: 2.81s	remaining: 1.72s
# 186:	learn: 288.7024277	total: 2.82s	remaining: 1.71s
# 187:	learn: 288.7006366	total: 2.84s	remaining: 1.69s
# 188:	learn: 288.6985419	total: 2.85s	remaining: 1.67s
# 189:	learn: 288.6943937	total: 2.86s	remaining: 1.66s
# 190:	learn: 288.6909452	total: 2.88s	remaining: 1.64s
# 191:	learn: 288.6852851	total: 2.89s	remaining: 1.63s
# 192:	learn: 288.6821780	total: 2.91s	remaining: 1.61s
# 193:	learn: 288.6797897	total: 2.92s	remaining: 1.6s
# 194:	learn: 288.6769195	total: 2.94s	remaining: 1.58s
# 195:	learn: 288.6748084	total: 2.95s	remaining: 1.57s
# 196:	learn: 288.6714526	total: 2.97s	remaining: 1.55s
# 197:	learn: 288.6686871	total: 2.98s	remaining: 1.54s
# 198:	learn: 288.6607944	total: 3s	remaining: 1.52s
# 199:	learn: 288.6590199	total: 3.01s	remaining: 1.5s
# 200:	learn: 288.6563325	total: 3.02s	remaining: 1.49s
# 201:	learn: 288.6520293	total: 3.04s	remaining: 1.47s
# 202:	learn: 288.6493359	total: 3.05s	remaining: 1.46s
# 203:	learn: 288.6469778	total: 3.07s	remaining: 1.44s
# 204:	learn: 288.6439012	total: 3.08s	remaining: 1.43s
# 205:	learn: 288.6416977	total: 3.1s	remaining: 1.41s
# 206:	learn: 288.6395882	total: 3.11s	remaining: 1.4s
# 207:	learn: 288.6362355	total: 3.13s	remaining: 1.38s
# 208:	learn: 288.6333582	total: 3.14s	remaining: 1.37s
# 209:	learn: 288.6309842	total: 3.15s	remaining: 1.35s
# 210:	learn: 288.6290111	total: 3.17s	remaining: 1.34s
# 211:	learn: 288.6272621	total: 3.18s	remaining: 1.32s
# 212:	learn: 288.6252224	total: 3.2s	remaining: 1.31s
# 213:	learn: 288.6235940	total: 3.21s	remaining: 1.29s
# 214:	learn: 288.6217592	total: 3.23s	remaining: 1.27s
# 215:	learn: 288.6188620	total: 3.24s	remaining: 1.26s
# 216:	learn: 288.6170608	total: 3.25s	remaining: 1.24s
# 217:	learn: 288.6138502	total: 3.27s	remaining: 1.23s
# 218:	learn: 288.6108964	total: 3.28s	remaining: 1.21s
# 219:	learn: 288.6092011	total: 3.29s	remaining: 1.2s
# 220:	learn: 288.6062330	total: 3.31s	remaining: 1.18s
# 221:	learn: 288.6031128	total: 3.32s	remaining: 1.17s
# 222:	learn: 288.6004045	total: 3.34s	remaining: 1.15s
# 223:	learn: 288.5976178	total: 3.35s	remaining: 1.14s
# 224:	learn: 288.5950900	total: 3.37s	remaining: 1.12s
# 225:	learn: 288.5932198	total: 3.38s	remaining: 1.11s
# 226:	learn: 288.5910377	total: 3.4s	remaining: 1.09s
# 227:	learn: 288.5890650	total: 3.41s	remaining: 1.08s
# 228:	learn: 288.5864956	total: 3.43s	remaining: 1.06s
# 229:	learn: 288.5842728	total: 3.44s	remaining: 1.05s
# 230:	learn: 288.5804675	total: 3.45s	remaining: 1.03s
# 231:	learn: 288.5765307	total: 3.47s	remaining: 1.02s
# 232:	learn: 288.5741665	total: 3.48s	remaining: 1s
# 233:	learn: 288.5718742	total: 3.5s	remaining: 987ms
# 234:	learn: 288.5669639	total: 3.51s	remaining: 972ms
# 235:	learn: 288.5645923	total: 3.53s	remaining: 956ms
# 236:	learn: 288.5618349	total: 3.54s	remaining: 941ms
# 237:	learn: 288.5589330	total: 3.55s	remaining: 926ms
# 238:	learn: 288.5565017	total: 3.57s	remaining: 911ms
# 239:	learn: 288.5542965	total: 3.58s	remaining: 896ms
# 240:	learn: 288.5530644	total: 3.6s	remaining: 880ms
# 241:	learn: 288.5497746	total: 3.61s	remaining: 866ms
# 242:	learn: 288.5474390	total: 3.63s	remaining: 850ms
# 243:	learn: 288.5455110	total: 3.64s	remaining: 835ms
# 244:	learn: 288.5439272	total: 3.65s	remaining: 820ms
# 245:	learn: 288.5417442	total: 3.67s	remaining: 805ms
# 246:	learn: 288.5401788	total: 3.68s	remaining: 790ms
# 247:	learn: 288.5384905	total: 3.69s	remaining: 775ms
# 248:	learn: 288.5365538	total: 3.71s	remaining: 760ms
# 249:	learn: 288.5350257	total: 3.72s	remaining: 745ms
# 250:	learn: 288.5325214	total: 3.74s	remaining: 730ms
# 251:	learn: 288.5304970	total: 3.75s	remaining: 715ms
# 252:	learn: 288.5288877	total: 3.77s	remaining: 700ms
# 253:	learn: 288.5270541	total: 3.78s	remaining: 685ms
# 254:	learn: 288.5249020	total: 3.79s	remaining: 670ms
# 255:	learn: 288.5221851	total: 3.81s	remaining: 655ms
# 256:	learn: 288.5199202	total: 3.83s	remaining: 640ms
# 257:	learn: 288.5176343	total: 3.84s	remaining: 625ms
# 258:	learn: 288.5160937	total: 3.85s	remaining: 610ms
# 259:	learn: 288.5138017	total: 3.87s	remaining: 595ms
# 260:	learn: 288.5121009	total: 3.88s	remaining: 580ms
# 261:	learn: 288.5096543	total: 3.9s	remaining: 566ms
# 262:	learn: 288.5074900	total: 3.91s	remaining: 551ms
# 263:	learn: 288.5055522	total: 3.93s	remaining: 536ms
# 264:	learn: 288.5037948	total: 3.94s	remaining: 521ms
# 265:	learn: 288.5019412	total: 3.96s	remaining: 506ms
# 266:	learn: 288.4996905	total: 3.97s	remaining: 491ms
# 267:	learn: 288.4979683	total: 3.99s	remaining: 476ms
# 268:	learn: 288.4961323	total: 4s	remaining: 461ms
# 269:	learn: 288.4946669	total: 4.02s	remaining: 446ms
# 270:	learn: 288.4924336	total: 4.03s	remaining: 431ms
# 271:	learn: 288.4896224	total: 4.04s	remaining: 416ms
# 272:	learn: 288.4866524	total: 4.06s	remaining: 402ms
# 273:	learn: 288.4851626	total: 4.08s	remaining: 387ms
# 274:	learn: 288.4839961	total: 4.09s	remaining: 372ms
# 275:	learn: 288.4822478	total: 4.1s	remaining: 357ms
# 276:	learn: 288.4800805	total: 4.12s	remaining: 342ms
# 277:	learn: 288.4773464	total: 4.13s	remaining: 327ms
# 278:	learn: 288.4756763	total: 4.15s	remaining: 312ms
# 279:	learn: 288.4729611	total: 4.16s	remaining: 297ms
# 280:	learn: 288.4709987	total: 4.18s	remaining: 282ms
# 281:	learn: 288.4695323	total: 4.19s	remaining: 267ms
# 282:	learn: 288.4684614	total: 4.2s	remaining: 253ms
# 283:	learn: 288.4668446	total: 4.22s	remaining: 238ms
# 284:	learn: 288.4656231	total: 4.23s	remaining: 223ms
# 285:	learn: 288.4643598	total: 4.25s	remaining: 208ms
# 286:	learn: 288.4634650	total: 4.26s	remaining: 193ms
# 287:	learn: 288.4620224	total: 4.27s	remaining: 178ms
# 288:	learn: 288.4607525	total: 4.29s	remaining: 163ms
# 289:	learn: 288.4586108	total: 4.3s	remaining: 148ms
# 290:	learn: 288.4553380	total: 4.32s	remaining: 134ms
# 291:	learn: 288.4539022	total: 4.33s	remaining: 119ms
# 292:	learn: 288.4515941	total: 4.34s	remaining: 104ms
# 293:	learn: 288.4497201	total: 4.36s	remaining: 89ms
# 294:	learn: 288.4471129	total: 4.38s	remaining: 74.2ms
# 295:	learn: 288.4438741	total: 4.39s	remaining: 59.3ms
# 296:	learn: 288.4427310	total: 4.4s	remaining: 44.5ms
# 297:	learn: 288.4408975	total: 4.42s	remaining: 29.7ms
# 298:	learn: 288.4386349	total: 4.43s	remaining: 14.8ms
# 299:	learn: 288.4369719	total: 4.45s	remaining: 0us

# %%
print('Best score: {}, Best params: {}'.format(round(best_rmse, 4), cat_search.best_params_))
# Out:
# Best score: 289.041, Best params: {'cat_features': ['gender', 'smoker', 'region_1', 'region_2', 'region_3', 'medical_1', 'medical_2', 'medical_3', 'family_1', 'family_2', 'family_3', 'exercise_1', 'exercise_2', 'exercise_3', 'occupation_1', 'occupation_2', 'occupation_3', 'level_1', 'level_2'], 'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 300, 'random_state': 42}

# %% [markdown]
# CatBoostRegressor 최적 파라미터
# - learning_rate: 0.5
# - max_depth: 3
# - n_estimators: 300

# %% [markdown]
# CatBoostRegressor 점수 비교
# - 최적화 전: 289.3760 최적화 후: 289.041

# %%
# LGBMRegressor 하이퍼 파라미터 튜닝
lgbm_params = {
    'num_leaves': [25, 31, 35], # 하나의 트리가 가질 수 있는 최대 리프 개수
    'learning_rate': [0.01, 0.05, 0.1, 0.5],
    'n_estimators': [100, 300, 500, 700],
    'max_depth': [3, 7, 11],
    'random_state': [42]
}

lgbm_search = GridSearchCV(lgbm, param_grid=lgbm_params, cv=5, 
                           scoring='neg_mean_squared_error', n_jobs=-1)
lgbm_search.fit(train_input, train_target)
best_mse = (-1) * lgbm_search.best_score_
best_rmse = np.sqrt(best_mse)

print('Best score: {}, Best params: {}'.format(round(best_rmse, 4), lgbm_search.best_params_))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010812 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 349
# [LightGBM] [Info] Number of data points in the train set: 500000, number of used features: 22
# [LightGBM] [Info] Start training from score 16738.598934
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Best score: 292.7539, Best params: {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 700, 'num_leaves': 31, 'random_state': 42}

# %% [markdown]
# LGBMRegressor 최적 파라미터
# - learning rate: 0.5
# - max_depth: 3
# - n_estimators: 700
# - num_leaves: 31

# %% [markdown]
# LGBMRegressor 점수 비교
# - 최적화 전: 330.1428 최적화 후: 292.7539

# %%
# XGBRegressor 하이퍼 파라미터 튜닝
xgb_params = {
    'n_estimators': [100, 300, 500, 700],
    'max_depth': [3, 7, 11],
    'learning_rate': [0.01, 0.05, 0.1, 0.5],
    'random_state': [42]
}

xgb_search = GridSearchCV(xgb, param_grid=xgb_params, cv=5,
                          scoring='neg_mean_squared_error', n_jobs=-1)
xgb_search.fit(train_input, train_target)
best_mse = (-1) * xgb_search.best_score_
best_rmse = np.sqrt(best_mse)

print('Best score: {}, Best params: {}'.format(round(best_rmse, 4), xgb_search.best_params_))
# Out:
# Best score: 292.0947, Best params: {'learning_rate': 0.5, 'max_depth': 3, 'n_estimators': 700, 'n_jobs': -1, 'random_state': 42}

# %% [markdown]
# XGBRegressor 최적 파라미터
# - n_estimators: 700
# - max_depth: 3
# - learning_rate: 0.5

# %% [markdown]
# XGBRegressor 점수 비교
# - 최적화 전: 339.2580 최적화 후: 292.0947

# %% [markdown]
# 모델링 점수 비교
# - CatBoostRegressor 약 0.33 개선
# - LGBMRegressor 약 33 개선
# - XGBRegressor 약 47 개선

# %% [markdown]
# ## 결과

# %%
# LinearRegression은 하이퍼 파라미터 튜닝을 진행하지 않고 r2 score만 확인
lr.fit(train_input, train_target)
lr_pred = lr.predict(test_input)

lr_r2 = r2_score(test_target, lr_pred)
print('Linear Regression r2 score: {}'.format(lr_r2))
# Out:
# Linear Regression r2 score: 0.9941797700018101

# %%
# CatBoostRegressor 성능 확인
cat_features = ['gender', 'smoker', 'region_1', 'region_2',
       'region_3', 'medical_1', 'medical_2', 'medical_3', 'family_1',
       'family_2', 'family_3', 'exercise_1', 'exercise_2', 'exercise_3',
       'occupation_1', 'occupation_2', 'occupation_3', 'level_1', 'level_2']

cat = CatBoostRegressor(learning_rate=0.5, max_depth=3, n_estimators=300, 
                        cat_features=cat_features, random_state=42)
cat.fit(train_input, train_target)
cat_pred = cat.predict(test_input)
cat_r2 = r2_score(test_target, cat_pred)
print('CatBoostRegressor r2 score: {}'.format(cat_r2))
# Out:
# 0:	learn: 3144.0368249	total: 215ms	remaining: 1m 4s
# 1:	learn: 2406.4379529	total: 255ms	remaining: 38s
# 2:	learn: 2090.5920053	total: 286ms	remaining: 28.3s
# 3:	learn: 1826.9355645	total: 318ms	remaining: 23.5s
# 4:	learn: 1669.0688272	total: 352ms	remaining: 20.8s
# 5:	learn: 1412.9797944	total: 397ms	remaining: 19.4s
# 6:	learn: 1294.5657521	total: 431ms	remaining: 18s
# 7:	learn: 1205.2288823	total: 461ms	remaining: 16.8s
# 8:	learn: 1089.2889575	total: 494ms	remaining: 16s
# 9:	learn: 985.5527511	total: 527ms	remaining: 15.3s
# 10:	learn: 915.2182624	total: 557ms	remaining: 14.6s
# 11:	learn: 804.1410630	total: 587ms	remaining: 14.1s
# 12:	learn: 759.9780879	total: 616ms	remaining: 13.6s
# 13:	learn: 721.3661195	total: 657ms	remaining: 13.4s
# 14:	learn: 677.4994232	total: 692ms	remaining: 13.1s
# 15:	learn: 641.2838652	total: 720ms	remaining: 12.8s
# 16:	learn: 600.9167342	total: 743ms	remaining: 12.4s
# 17:	learn: 571.9255514	total: 765ms	remaining: 12s
# 18:	learn: 525.5000102	total: 789ms	remaining: 11.7s
# 19:	learn: 506.8057806	total: 810ms	remaining: 11.3s
# 20:	learn: 479.4971406	total: 843ms	remaining: 11.2s
# 21:	learn: 463.5331943	total: 875ms	remaining: 11.1s
# 22:	learn: 424.9663902	total: 913ms	remaining: 11s
# 23:	learn: 411.7893160	total: 941ms	remaining: 10.8s
# 24:	learn: 400.0924220	total: 965ms	remaining: 10.6s
# 25:	learn: 383.6829010	total: 989ms	remaining: 10.4s
# 26:	learn: 373.3397829	total: 1.01s	remaining: 10.2s
# 27:	learn: 365.9831420	total: 1.04s	remaining: 10.1s
# 28:	learn: 359.6733328	total: 1.06s	remaining: 9.9s
# 29:	learn: 354.9874258	total: 1.09s	remaining: 9.78s
# 30:	learn: 343.9004055	total: 1.11s	remaining: 9.67s
# 31:	learn: 339.6529804	total: 1.14s	remaining: 9.52s
# 32:	learn: 336.0373798	total: 1.16s	remaining: 9.37s
# 33:	learn: 332.8567114	total: 1.18s	remaining: 9.23s
# 34:	learn: 328.0720450	total: 1.2s	remaining: 9.11s
# 35:	learn: 322.5670704	total: 1.23s	remaining: 8.99s
# 36:	learn: 320.2272011	total: 1.25s	remaining: 8.88s
# 37:	learn: 316.5742577	total: 1.27s	remaining: 8.78s
# 38:	learn: 313.7684287	total: 1.3s	remaining: 8.68s
# 39:	learn: 310.6662734	total: 1.32s	remaining: 8.59s
# 40:	learn: 309.3347015	total: 1.34s	remaining: 8.49s
# 41:	learn: 308.0325921	total: 1.37s	remaining: 8.4s
# 42:	learn: 307.0202111	total: 1.39s	remaining: 8.3s
# 43:	learn: 306.1174071	total: 1.41s	remaining: 8.21s
# 44:	learn: 304.8442424	total: 1.43s	remaining: 8.13s
# 45:	learn: 303.7242856	total: 1.46s	remaining: 8.05s
# 46:	learn: 302.4329440	total: 1.48s	remaining: 7.98s
# 47:	learn: 301.7016645	total: 1.5s	remaining: 7.9s
# 48:	learn: 301.1614619	total: 1.53s	remaining: 7.84s
# 49:	learn: 300.3577142	total: 1.55s	remaining: 7.77s
# 50:	learn: 298.9215284	total: 1.58s	remaining: 7.72s
# 51:	learn: 297.8656317	total: 1.61s	remaining: 7.66s
# 52:	learn: 297.5087430	total: 1.63s	remaining: 7.59s
# 53:	learn: 296.8485363	total: 1.65s	remaining: 7.54s
# 54:	learn: 296.5560513	total: 1.68s	remaining: 7.46s
# 55:	learn: 295.6333296	total: 1.7s	remaining: 7.4s
# 56:	learn: 295.4008201	total: 1.72s	remaining: 7.34s
# 57:	learn: 295.1789204	total: 1.75s	remaining: 7.29s
# 58:	learn: 294.9096239	total: 1.77s	remaining: 7.24s
# 59:	learn: 294.5781410	total: 1.8s	remaining: 7.18s
# 60:	learn: 293.9912034	total: 1.82s	remaining: 7.13s
# 61:	learn: 293.8045058	total: 1.84s	remaining: 7.08s
# 62:	learn: 293.6463346	total: 1.87s	remaining: 7.02s
# 63:	learn: 293.4402747	total: 1.89s	remaining: 6.97s
# 64:	learn: 292.9396454	total: 1.91s	remaining: 6.92s
# 65:	learn: 292.6327335	total: 1.94s	remaining: 6.86s
# 66:	learn: 292.4031927	total: 1.96s	remaining: 6.82s
# 67:	learn: 292.3212625	total: 1.99s	remaining: 6.77s
# 68:	learn: 292.0006840	total: 2.01s	remaining: 6.73s
# 69:	learn: 291.7382951	total: 2.03s	remaining: 6.69s
# 70:	learn: 291.6797902	total: 2.06s	remaining: 6.64s
# 71:	learn: 291.5372787	total: 2.08s	remaining: 6.59s
# 72:	learn: 291.3505632	total: 2.11s	remaining: 6.55s
# 73:	learn: 291.2212685	total: 2.13s	remaining: 6.5s
# 74:	learn: 291.1233700	total: 2.15s	remaining: 6.45s
# 75:	learn: 290.9282929	total: 2.17s	remaining: 6.41s
# 76:	learn: 290.8752383	total: 2.2s	remaining: 6.36s
# 77:	learn: 290.7945773	total: 2.22s	remaining: 6.32s
# 78:	learn: 290.7576945	total: 2.24s	remaining: 6.27s
# 79:	learn: 290.6843967	total: 2.27s	remaining: 6.23s
# 80:	learn: 290.6372959	total: 2.29s	remaining: 6.19s
# 81:	learn: 290.5507376	total: 2.31s	remaining: 6.15s
# 82:	learn: 290.4983033	total: 2.34s	remaining: 6.11s
# 83:	learn: 290.4227307	total: 2.36s	remaining: 6.07s
# 84:	learn: 290.3132338	total: 2.39s	remaining: 6.04s
# 85:	learn: 290.1959030	total: 2.41s	remaining: 6s
# 86:	learn: 290.0467164	total: 2.44s	remaining: 5.97s
# 87:	learn: 289.9825557	total: 2.46s	remaining: 5.92s
# 88:	learn: 289.9596576	total: 2.48s	remaining: 5.89s
# 89:	learn: 289.9021402	total: 2.51s	remaining: 5.85s
# 90:	learn: 289.8785527	total: 2.53s	remaining: 5.81s
# 91:	learn: 289.8559329	total: 2.55s	remaining: 5.77s
# 92:	learn: 289.8060786	total: 2.58s	remaining: 5.74s
# 93:	learn: 289.7836431	total: 2.6s	remaining: 5.7s
# 94:	learn: 289.7480833	total: 2.63s	remaining: 5.67s
# 95:	learn: 289.7058009	total: 2.65s	remaining: 5.64s
# 96:	learn: 289.6642898	total: 2.68s	remaining: 5.61s
# 97:	learn: 289.6207821	total: 2.71s	remaining: 5.58s
# 98:	learn: 289.5890061	total: 2.73s	remaining: 5.54s
# 99:	learn: 289.5647495	total: 2.76s	remaining: 5.51s
# 100:	learn: 289.5247068	total: 2.78s	remaining: 5.48s
# 101:	learn: 289.5106922	total: 2.8s	remaining: 5.44s
# 102:	learn: 289.5013941	total: 2.83s	remaining: 5.41s
# 103:	learn: 289.4663819	total: 2.85s	remaining: 5.38s
# 104:	learn: 289.4544710	total: 2.88s	remaining: 5.34s
# 105:	learn: 289.4087722	total: 2.9s	remaining: 5.31s
# 106:	learn: 289.3811602	total: 2.93s	remaining: 5.28s
# 107:	learn: 289.3549205	total: 2.95s	remaining: 5.25s
# 108:	learn: 289.3416772	total: 2.98s	remaining: 5.22s
# 109:	learn: 289.3044416	total: 3s	remaining: 5.18s
# 110:	learn: 289.2861507	total: 3.02s	remaining: 5.15s
# 111:	learn: 289.2770088	total: 3.05s	remaining: 5.12s
# 112:	learn: 289.2718561	total: 3.07s	remaining: 5.09s
# 113:	learn: 289.2573858	total: 3.1s	remaining: 5.06s
# 114:	learn: 289.2208312	total: 3.13s	remaining: 5.03s
# 115:	learn: 289.1969505	total: 3.15s	remaining: 5s
# 116:	learn: 289.1758218	total: 3.17s	remaining: 4.96s
# 117:	learn: 289.1698758	total: 3.19s	remaining: 4.92s
# 118:	learn: 289.1560138	total: 3.22s	remaining: 4.89s
# 119:	learn: 289.1406339	total: 3.24s	remaining: 4.86s
# 120:	learn: 289.1165502	total: 3.27s	remaining: 4.83s
# 121:	learn: 289.1113322	total: 3.29s	remaining: 4.8s
# 122:	learn: 289.0998847	total: 3.31s	remaining: 4.77s
# 123:	learn: 289.0868014	total: 3.34s	remaining: 4.74s
# 124:	learn: 289.0751528	total: 3.36s	remaining: 4.71s
# 125:	learn: 289.0691098	total: 3.38s	remaining: 4.67s
# 126:	learn: 289.0661128	total: 3.4s	remaining: 4.64s
# 127:	learn: 289.0502983	total: 3.42s	remaining: 4.6s
# 128:	learn: 289.0437106	total: 3.45s	remaining: 4.57s
# 129:	learn: 289.0386660	total: 3.47s	remaining: 4.54s
# 130:	learn: 289.0310447	total: 3.5s	remaining: 4.51s
# 131:	learn: 289.0196051	total: 3.52s	remaining: 4.48s
# 132:	learn: 289.0056953	total: 3.54s	remaining: 4.45s
# 133:	learn: 288.9878350	total: 3.57s	remaining: 4.42s
# 134:	learn: 288.9747262	total: 3.59s	remaining: 4.39s
# 135:	learn: 288.9664147	total: 3.62s	remaining: 4.36s
# 136:	learn: 288.9550164	total: 3.65s	remaining: 4.34s
# 137:	learn: 288.9514850	total: 3.67s	remaining: 4.31s
# 138:	learn: 288.9453820	total: 3.69s	remaining: 4.28s
# 139:	learn: 288.9421173	total: 3.71s	remaining: 4.25s
# 140:	learn: 288.9308771	total: 3.74s	remaining: 4.21s
# 141:	learn: 288.9258835	total: 3.76s	remaining: 4.18s
# 142:	learn: 288.9228776	total: 3.78s	remaining: 4.15s
# 143:	learn: 288.9117486	total: 3.8s	remaining: 4.12s
# 144:	learn: 288.9094120	total: 3.83s	remaining: 4.09s
# 145:	learn: 288.9053223	total: 3.85s	remaining: 4.06s
# 146:	learn: 288.9006382	total: 3.87s	remaining: 4.03s
# 147:	learn: 288.8981707	total: 3.9s	remaining: 4s
# 148:	learn: 288.8955314	total: 3.92s	remaining: 3.97s
# 149:	learn: 288.8914609	total: 3.94s	remaining: 3.94s
# 150:	learn: 288.8871231	total: 3.97s	remaining: 3.92s
# 151:	learn: 288.8834047	total: 3.99s	remaining: 3.88s
# 152:	learn: 288.8806662	total: 4.01s	remaining: 3.86s
# 153:	learn: 288.8769118	total: 4.04s	remaining: 3.83s
# 154:	learn: 288.8748049	total: 4.06s	remaining: 3.8s
# 155:	learn: 288.8644697	total: 4.09s	remaining: 3.77s
# 156:	learn: 288.8618581	total: 4.12s	remaining: 3.75s
# 157:	learn: 288.8560440	total: 4.14s	remaining: 3.72s
# 158:	learn: 288.8534700	total: 4.17s	remaining: 3.69s
# 159:	learn: 288.8516491	total: 4.19s	remaining: 3.67s
# 160:	learn: 288.8490537	total: 4.21s	remaining: 3.64s
# 161:	learn: 288.8472498	total: 4.23s	remaining: 3.6s
# 162:	learn: 288.8418483	total: 4.26s	remaining: 3.58s
# 163:	learn: 288.8380247	total: 4.28s	remaining: 3.55s
# 164:	learn: 288.8358684	total: 4.3s	remaining: 3.52s
# 165:	learn: 288.8330251	total: 4.32s	remaining: 3.49s
# 166:	learn: 288.8304486	total: 4.35s	remaining: 3.46s
# 167:	learn: 288.8276987	total: 4.37s	remaining: 3.43s
# 168:	learn: 288.8259063	total: 4.39s	remaining: 3.41s
# 169:	learn: 288.8199149	total: 4.42s	remaining: 3.38s
# 170:	learn: 288.8140437	total: 4.44s	remaining: 3.35s
# 171:	learn: 288.8109575	total: 4.47s	remaining: 3.32s
# 172:	learn: 288.8065879	total: 4.49s	remaining: 3.29s
# 173:	learn: 288.8039029	total: 4.51s	remaining: 3.27s
# 174:	learn: 288.8006058	total: 4.54s	remaining: 3.24s
# 175:	learn: 288.7955630	total: 4.56s	remaining: 3.21s
# 176:	learn: 288.7938776	total: 4.58s	remaining: 3.19s
# 177:	learn: 288.7871049	total: 4.61s	remaining: 3.16s
# 178:	learn: 288.7824275	total: 4.63s	remaining: 3.13s
# 179:	learn: 288.7779425	total: 4.65s	remaining: 3.1s
# 180:	learn: 288.7764507	total: 4.68s	remaining: 3.07s
# 181:	learn: 288.7749984	total: 4.7s	remaining: 3.04s
# 182:	learn: 288.7722851	total: 4.72s	remaining: 3.02s
# 183:	learn: 288.7700421	total: 4.75s	remaining: 2.99s
# 184:	learn: 288.7673262	total: 4.77s	remaining: 2.96s
# 185:	learn: 288.7646803	total: 4.79s	remaining: 2.94s
# 186:	learn: 288.7633550	total: 4.82s	remaining: 2.91s
# 187:	learn: 288.7606402	total: 4.84s	remaining: 2.88s
# 188:	learn: 288.7562830	total: 4.86s	remaining: 2.85s
# 189:	learn: 288.7546188	total: 4.88s	remaining: 2.83s
# 190:	learn: 288.7528704	total: 4.91s	remaining: 2.8s
# 191:	learn: 288.7509860	total: 4.93s	remaining: 2.77s
# 192:	learn: 288.7488824	total: 4.96s	remaining: 2.75s
# 193:	learn: 288.7474470	total: 4.98s	remaining: 2.72s
# 194:	learn: 288.7457975	total: 5s	remaining: 2.69s
# 195:	learn: 288.7440345	total: 5.03s	remaining: 2.67s
# 196:	learn: 288.7416298	total: 5.05s	remaining: 2.64s
# 197:	learn: 288.7395897	total: 5.08s	remaining: 2.62s
# 198:	learn: 288.7378391	total: 5.1s	remaining: 2.59s
# 199:	learn: 288.7363302	total: 5.12s	remaining: 2.56s
# 200:	learn: 288.7350061	total: 5.14s	remaining: 2.53s
# 201:	learn: 288.7332762	total: 5.16s	remaining: 2.5s
# 202:	learn: 288.7308801	total: 5.19s	remaining: 2.48s
# 203:	learn: 288.7289631	total: 5.21s	remaining: 2.45s
# 204:	learn: 288.7274738	total: 5.24s	remaining: 2.43s
# 205:	learn: 288.7244082	total: 5.26s	remaining: 2.4s
# 206:	learn: 288.7231009	total: 5.28s	remaining: 2.37s
# 207:	learn: 288.7216796	total: 5.3s	remaining: 2.35s
# 208:	learn: 288.7204581	total: 5.32s	remaining: 2.32s
# 209:	learn: 288.7187160	total: 5.35s	remaining: 2.29s
# 210:	learn: 288.7169183	total: 5.37s	remaining: 2.26s
# 211:	learn: 288.7159140	total: 5.39s	remaining: 2.24s
# 212:	learn: 288.7142839	total: 5.41s	remaining: 2.21s
# 213:	learn: 288.7105952	total: 5.44s	remaining: 2.19s
# 214:	learn: 288.7090103	total: 5.46s	remaining: 2.16s
# 215:	learn: 288.7075870	total: 5.49s	remaining: 2.13s
# 216:	learn: 288.7061338	total: 5.51s	remaining: 2.11s
# 217:	learn: 288.7045101	total: 5.53s	remaining: 2.08s
# 218:	learn: 288.7028678	total: 5.56s	remaining: 2.06s
# 219:	learn: 288.7013893	total: 5.58s	remaining: 2.03s
# 220:	learn: 288.6984611	total: 5.61s	remaining: 2s
# 221:	learn: 288.6967940	total: 5.63s	remaining: 1.98s
# 222:	learn: 288.6951732	total: 5.65s	remaining: 1.95s
# 223:	learn: 288.6941415	total: 5.67s	remaining: 1.92s
# 224:	learn: 288.6918103	total: 5.69s	remaining: 1.9s
# 225:	learn: 288.6903564	total: 5.72s	remaining: 1.87s
# 226:	learn: 288.6889232	total: 5.74s	remaining: 1.84s
# 227:	learn: 288.6873130	total: 5.76s	remaining: 1.82s
# 228:	learn: 288.6857592	total: 5.79s	remaining: 1.79s
# 229:	learn: 288.6837953	total: 5.81s	remaining: 1.77s
# 230:	learn: 288.6816480	total: 5.83s	remaining: 1.74s
# 231:	learn: 288.6803466	total: 5.85s	remaining: 1.72s
# 232:	learn: 288.6788484	total: 5.88s	remaining: 1.69s
# 233:	learn: 288.6766670	total: 5.9s	remaining: 1.66s
# 234:	learn: 288.6753365	total: 5.92s	remaining: 1.64s
# 235:	learn: 288.6739511	total: 5.94s	remaining: 1.61s
# 236:	learn: 288.6728327	total: 5.97s	remaining: 1.58s
# 237:	learn: 288.6713123	total: 5.99s	remaining: 1.56s
# 238:	learn: 288.6702296	total: 6.02s	remaining: 1.53s
# 239:	learn: 288.6687796	total: 6.04s	remaining: 1.51s
# 240:	learn: 288.6668398	total: 6.06s	remaining: 1.48s
# 241:	learn: 288.6657416	total: 6.08s	remaining: 1.46s
# 242:	learn: 288.6641940	total: 6.11s	remaining: 1.43s
# 243:	learn: 288.6627620	total: 6.13s	remaining: 1.41s
# 244:	learn: 288.6614426	total: 6.15s	remaining: 1.38s
# 245:	learn: 288.6602524	total: 6.17s	remaining: 1.35s
# 246:	learn: 288.6578579	total: 6.2s	remaining: 1.33s
# 247:	learn: 288.6564984	total: 6.22s	remaining: 1.3s
# 248:	learn: 288.6550841	total: 6.24s	remaining: 1.28s
# 249:	learn: 288.6536416	total: 6.26s	remaining: 1.25s
# 250:	learn: 288.6523575	total: 6.29s	remaining: 1.23s
# 251:	learn: 288.6508011	total: 6.31s	remaining: 1.2s
# 252:	learn: 288.6499681	total: 6.33s	remaining: 1.18s
# 253:	learn: 288.6488527	total: 6.36s	remaining: 1.15s
# 254:	learn: 288.6478360	total: 6.38s	remaining: 1.13s
# 255:	learn: 288.6469761	total: 6.4s	remaining: 1.1s
# 256:	learn: 288.6457530	total: 6.42s	remaining: 1.07s
# 257:	learn: 288.6444871	total: 6.44s	remaining: 1.05s
# 258:	learn: 288.6431957	total: 6.47s	remaining: 1.02s
# 259:	learn: 288.6419698	total: 6.49s	remaining: 998ms
# 260:	learn: 288.6410018	total: 6.51s	remaining: 973ms
# 261:	learn: 288.6396202	total: 6.53s	remaining: 948ms
# 262:	learn: 288.6382800	total: 6.56s	remaining: 923ms
# 263:	learn: 288.6361777	total: 6.58s	remaining: 897ms
# 264:	learn: 288.6343945	total: 6.6s	remaining: 872ms
# 265:	learn: 288.6335890	total: 6.62s	remaining: 846ms
# 266:	learn: 288.6321893	total: 6.64s	remaining: 821ms
# 267:	learn: 288.6314925	total: 6.67s	remaining: 796ms
# 268:	learn: 288.6296062	total: 6.69s	remaining: 771ms
# 269:	learn: 288.6274776	total: 6.71s	remaining: 746ms
# 270:	learn: 288.6264028	total: 6.73s	remaining: 720ms
# 271:	learn: 288.6250319	total: 6.75s	remaining: 695ms
# 272:	learn: 288.6241001	total: 6.78s	remaining: 670ms
# 273:	learn: 288.6230074	total: 6.8s	remaining: 646ms
# 274:	learn: 288.6208223	total: 6.84s	remaining: 622ms
# 275:	learn: 288.6199268	total: 6.87s	remaining: 597ms
# 276:	learn: 288.6188905	total: 6.89s	remaining: 572ms
# 277:	learn: 288.6171536	total: 6.91s	remaining: 547ms
# 278:	learn: 288.6152252	total: 6.93s	remaining: 522ms
# 279:	learn: 288.6141176	total: 6.95s	remaining: 497ms
# 280:	learn: 288.6132754	total: 6.97s	remaining: 472ms
# 281:	learn: 288.6126756	total: 7s	remaining: 447ms
# 282:	learn: 288.6117202	total: 7.02s	remaining: 422ms
# 283:	learn: 288.6109435	total: 7.04s	remaining: 397ms
# 284:	learn: 288.6085650	total: 7.07s	remaining: 372ms
# 285:	learn: 288.6072610	total: 7.09s	remaining: 347ms
# 286:	learn: 288.6063612	total: 7.11s	remaining: 322ms
# 287:	learn: 288.6051282	total: 7.13s	remaining: 297ms
# 288:	learn: 288.6035707	total: 7.16s	remaining: 272ms
# 289:	learn: 288.6026889	total: 7.18s	remaining: 248ms
# 290:	learn: 288.6014323	total: 7.2s	remaining: 223ms
# 291:	learn: 288.5993193	total: 7.23s	remaining: 198ms
# 292:	learn: 288.5980936	total: 7.25s	remaining: 173ms
# 293:	learn: 288.5968189	total: 7.27s	remaining: 148ms
# 294:	learn: 288.5958963	total: 7.29s	remaining: 124ms
# 295:	learn: 288.5948432	total: 7.32s	remaining: 98.9ms
# 296:	learn: 288.5939686	total: 7.34s	remaining: 74.2ms
# 297:	learn: 288.5923421	total: 7.36s	remaining: 49.4ms
# 298:	learn: 288.5908266	total: 7.38s	remaining: 24.7ms
# 299:	learn: 288.5892040	total: 7.41s	remaining: 0us
# CatBoostRegressor r2 score: 0.9957187606353748

# %%
# LGBMRegressor 성능 확인
lgbm = LGBMRegressor(learning_rate=0.5, max_depth=3, n_estimators=700, num_leaves=31, 
                     random_state=42, n_jobs=-1)
lgbm.fit(train_input, train_target)
lgbm_pred = lgbm.predict(test_input)
lgbm_r2 = r2_score(test_target, lgbm_pred)
print('LGBMRegressor r2 score: {}'.format(lgbm_r2))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011610 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 349
# [LightGBM] [Info] Number of data points in the train set: 800000, number of used features: 22
# [LightGBM] [Info] Start training from score 16736.848695
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor r2 score: 0.9956342037842927

# %%
# XGBRegressor 성능 확인
xgb = XGBRegressor(n_estimators=700, max_depth=3, learning_rate=0.5)
xgb.fit(train_input, train_target)
xgb_pred = xgb.predict(test_input)
xgb_r2 = r2_score(test_target, xgb_pred)
print('XGBRegressor r2 score: {}'.format(xgb_r2))
# Out:
# XGBRegressor r2 score: 0.9956287971009387

# %%
# Linear Regression 계수 확인
coef_df = pd.DataFrame({
    "Feature": train_input.columns,
    "Coefficient": lr.coef_
}).sort_values(by="Coefficient", ascending=False)
print(coef_df)
# Out:
#          Feature  Coefficient
# 20       level_1  5000.167337
# 4         smoker  4999.634041
# 8      medical_1  3001.275125
# 11      family_1  3000.740988
# 21       level_2  1999.920596
# 1         gender  1000.100663
# 19  occupation_3   501.353259
# 2            bmi   450.663643
# 3       children   341.944519
# 0            age   238.197775
# 6       region_2  -498.343261
# 5       region_1  -699.385941
# 7       region_3  -798.610152
# 17  occupation_1  -998.684797
# 12      family_2  -998.805370
# 15    exercise_2  -998.966824
# 9      medical_2 -1001.220227
# 18  occupation_2 -1499.317127
# 16    exercise_3 -1500.737116
# 10     medical_3 -1998.593286
# 13      family_3 -1999.255700
# 14    exercise_1 -2000.282031

# %%
# Linear Regression 속성 중요도 시각화
plt.barh(coef_df['Feature'], coef_df['Coefficient'])
plt.title('Linear Regression Feature Importances')
plt.show()

# %%
# CatBoostRegressor 속성 중요도 확인
importance_df = pd.DataFrame({
        "Feature": train_input.columns,
        "Importance": cat.feature_importances_
    }).sort_values(by="Importance", ascending=False)
print(importance_df)
# Out:
#          Feature  Importance
# 4         smoker   30.678264
# 20       level_1   19.617707
# 11      family_1   13.809048
# 8      medical_1   13.794441
# 21       level_2    3.288897
# 10     medical_3    2.975399
# 13      family_3    2.860299
# 14    exercise_1    2.122056
# 18  occupation_2    1.467989
# 16    exercise_3    1.333031
# 19  occupation_3    1.243689
# 1         gender    1.224932
# 2            bmi    1.062377
# 9      medical_2    0.809465
# 12      family_2    0.790550
# 17  occupation_1    0.688221
# 15    exercise_2    0.610854
# 3       children    0.570239
# 0            age    0.383437
# 7       region_3    0.291238
# 5       region_1    0.257181
# 6       region_2    0.120686

# %%
# CatBoostRegressor 속성 중요도 시각화
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.gca().invert_yaxis()
plt.title('CatBoostRegressor Feature Importances')
plt.show()

# %%
# LGBMRegressor 속성 중요도 확인
importance_df = pd.DataFrame({
        "Feature": train_input.columns,
        "Importance": lgbm.feature_importances_
    }).sort_values(by="Importance", ascending=False)
print(importance_df)
# Out:
#          Feature  Importance
# 2            bmi         874
# 0            age         452
# 3       children         451
# 20       level_1         427
# 21       level_2         360
# 4         smoker         290
# 9      medical_2         208
# 8      medical_1         205
# 12      family_2         189
# 17  occupation_1         174
# 16    exercise_3         163
# 11      family_1         161
# 10     medical_3         154
# 18  occupation_2         115
# 13      family_3         113
# 7       region_3         103
# 14    exercise_1         100
# 15    exercise_2          98
# 6       region_2          71
# 19  occupation_3          69
# 1         gender          63
# 5       region_1          60

# %%
# LGBMRegressor 속성 중요도 시각화
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.gca().invert_yaxis()
plt.title('LGBMRegressor Feature Importances')
plt.show()

# %%
# XGBRegressor 속성 중요도 확인
importance_df = pd.DataFrame({
        "Feature": train_input.columns,
        "Importance": xgb.feature_importances_
    }).sort_values(by="Importance", ascending=False)
print(importance_df)
# Out:
#          Feature  Importance
# 4         smoker    0.282573
# 11      family_1    0.166775
# 8      medical_1    0.126446
# 20       level_1    0.086216
# 13      family_3    0.074593
# 1         gender    0.066275
# 10     medical_3    0.040521
# 14    exercise_1    0.036302
# 18  occupation_2    0.027509
# 19  occupation_3    0.025417
# 21       level_2    0.018561
# 12      family_2    0.007292
# 16    exercise_3    0.007212
# 17  occupation_1    0.006591
# 5       region_1    0.005638
# 15    exercise_2    0.004373
# 9      medical_2    0.003886
# 6       region_2    0.003566
# 7       region_3    0.003474
# 2            bmi    0.002595
# 3       children    0.002305
# 0            age    0.001879

# %%
# XGBRegressor 속성 중요도 시각화
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.gca().invert_yaxis()
plt.title(' XGBRegressor Feature Importances')
plt.show()
